# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #🚀 Aula 4: O Fluxo de Trabalho Profissional (Scripts e Funções)
# Imagine que você trabalha em um banco. Todo santo dia, às 18h, chega uma matriz nova com as transações suspeitas de fraude. Você não vai abrir o Jupyter Notebook todo dia, rodar célula por célula e exportar manualmente.
#
# Você cria um script em Python que importa o NumPy, processa os dados automaticamente e cospe o relatório pronto.
#
# Como estruturar seu código como um profissional:
# No seu arquivo helper_functions.py, você cria funções genéricas (que aceitam qualquer array):
# ---
# Python
# Dentro do seu arquivo: helper_functions.py
#
# *import numpy as np*
#
# *def analisar_perdas(matriz_dados):*
#
#     Função profissional que recebe uma matriz e devolve
#     o faturamento total e os índices críticos de perda.
#
#     # 1. Calcula a soma total da última coluna (Faturamento)
#
#    *faturamento_total = np.sum(matriz_dados[:, -1])*
#
#    *return faturamento_total*

# %%
# E no seu Notebook principal (01-numpy-basico.ipynb), você apenas chama essa função:


# ==========================================
# NO SEU NOTEBOOK (.ipynb)
# ==========================================
import numpy as np

# PASSO 2A: Conectar a sua caixa de ferramentas ao Notebook
# Dizemos: "Do arquivo helper_functions, traga a função filtrar_valores_altos"
from helper_functions import filtrar_valores_altos

# PASSO 2B: Chegaram os dados reais do dia (Array NumPy)
vendas_hoje = np.array([1200, 6000, 4500, 9000, 3100])

# PASSO 2C: Chamar a função passando os dados reais
# O array 'vendas_hoje' entra no lugar do argumento 'vendas' da função
vendas_elite = filtrar_valores_altos(vendas_hoje)

# PASSO 2D: Visualizar o resultado final
print("Vendas acima de 5000:", vendas_elite)
# Saída na tela: [6000 9000]
# Out:
# Vendas acima de 5000: [6000 9000]

# %% [markdown]
# # 📝 Resumo Rápido da Aula 4 (Folha de Consulta)
# Scripts .py: Servem para guardar funções que você vai reutilizar muitas vezes.
#
# Notebooks .ipynb: Servem para testar, explorar os dados e apresentar gráficos.
#
# Sintaxe de Importação: from nome_do_arquivo import nome_da_função.
